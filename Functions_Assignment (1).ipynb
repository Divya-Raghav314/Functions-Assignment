# %% [markdown]
# #1. What is the difference between a function and a method in Python?
# Functions are independent block of code that can be called from anywhere while methods are associated with any class or object and need an object or class instance to be invoked.
# Example of function
# def function():
#      print("this is function")
# Example of method
# Class fruit():
#    def fruit_info(self):
#     print("this is fruit information")
#
#
# #2. Explain the concept of function arguments and parameters in Python?
# A parameter is a variable listed inside the parenthesis in the function definition while an arguement is the value which is expected from the function.
# Example-
# def function(name): #name is parameter
#   print("My name is", name)
#
# function(Divya)  #Divya is arguement
#
# #3. What are the different ways to define and call a function in Python?
# Functions are defined using def keyword or with a lambda expression.
# They are called using parenthesis().
# Example-
# def square(x):
#  return x*x
#  print(square(9))
#
# Double = lambda x:x*2
# print(double(7))
#
# #4. What is the purpose of the `return` statement in a Python function?
# Returning statement in python for serves two purpose:-
# 1. It helps in returning a value or multiple values from a function.
# 2. It helps in exiting the function.
#
# Example-
#
# def multi(a, b, c):
#  calc = a*b+c
#  return(calc)
#
# #5. What are iterators in Python and how do they differ from iterables?
# Iterators in python is an object that remember its position and let you get next item one by one by using next() function.
# example-
# a = "pwskills"
# t = iter(a)
# next(t)
# Iterables in python is an object/ sequential structure/data structure that is capable of returning all items one at a time.
# example-
# a = "pwskills"
# for i in a:
# print(i)
#
# #6.  Explain the concept of generators in Python and how they are defined?
# Generator is a type of function that gives one value at onetime using "yield" keyword, instead of returning all values.
# Generators are defined using yield keyword.
# example-
# def sq_num(n):
#  for i in range(n):
#   yield i**2  #generators
#
# a = sq_num(10)
# next (a)
#
# #7. What are the advantages of using generators over regular functions?
# Following are the advantages of generators over regular function:-
# 1. Generators stores one value at a time which ensures memory efficiency than regular functions.
# 2. Generators are more faster in time than regular functions as regular function return large data sets which is first computed but in generators it yields one value immediately.
# 3. Generators are easier to work with infinite and large data.
# example of generators-
# def sq_num(n):
#  for i in range(n):
#   yield i**2  #generators
#
# a = sq_num(10)
# next (a)
#
# example of regular functions-
# def multi(a, b, c):
#  calc = a*b+c
#  return(calc)
#
# #8. What is a lambda function in Python and when is it typically used?
# Lambda is a one line function that is anonymous function that can take any number of arguements but gives only one expression.
# syntax of lambda function-
# lambda arguements : expression
#
# Used-
# 1. It is used when you need a code for shorter time and faster.
# 2. when you don't want to name a function.
#
# add = lambda x, y: x+y
# add(4, 5)
#
# #9. Explain the purpose and usage of the `map()` function in Python?
# Map function executes a specified function for each of iterm of an iterable.
# syntax of map-
# map(function, iterables)
# It is used to apply a function to every item in an iterable.
# example-
# def sq_num(n):
#  return n**2
# l = [1, 2, 3, 4, 5]
# list(map(sq_num,l))
#
# #10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# 1. Map() is used to apply a function to every item in an iterable.
# syntax-
# map(function, iterables)
# example-
# def sq_num(n):
#  return n**2
# l = [1, 2, 3, 4, 5]
# list(map(sq_num,l))
#
# 2. reduce() is used to reduce an iterable by applying a function repeatedly till we got single value.
# syntax-
# reduce(function, iterables)
# example-
# l= [1, 2, 3, 4, 5]
# reduce(lambda x, y : x if x>y else y, l)
#
# 3. filter() is used to filter elements from an iterables based on function.
# syntax-
# filter(function,iterables)
# eg-
# l= [1, 2, 3, 4, 5]
# list(filter(lambda x : x % 2 == 0, l))
#
#
# #11.  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]
# ![image.png](data:image/png;base64,...)

# %%
#Practical Questions:

# %%
#1.  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
def sum_of_even(numbers):
  sum = 0
  for num in numbers:
    if num % 2 == 0:
      sum+=num
  return sum


sum_of_even(numbers)
# Out:
# 20

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
a = "Pwskills"
def return_reverse(a):
  return a[::-1]

return_reverse(a)
# Out:
# 'sllikswP'

# %%
#3  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

list1 = [1, 2, 3, 4, 5, 6]
def sq(list1):
  list2 = []
  for i in list1:
    list2.append(i**2)
  return list2

sq(list1)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
#4.Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime_num(n):
  if n < 2:
    return  False
  for i in range(2,int(n**0.5)+1):
    if n % i == 0:
      return False
  return True

for num in range(1,201):
  if is_prime_num(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %%
#5  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
terms.
def fib(n):
  a = 0
  b = 1
  for i in range(n):
    yield a
    a, b = b, a+b

for number in fib(5):
  print(number)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
#6 Write a generator function in Python that yields the powers of 2 up to a given exponent.
def power_of_two(n):
  for i in range(n):
    yield i**2

for powe in power_of_two(10):
  print(powe)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
#8  Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
x = [("name", 8), ("job", 2), ("company", 4)]
sorted_data = sorted(x,key = lambda x:x[1])
print(sorted_data)
# Out:
# [('job', 2), ('company', 4), ('name', 8)]

# %%
#7 Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_lines(filename):
    file = open(filename, 'r')
    try:
        for line in file:
            yield line  # Each line includes the newline character '\n'
    finally:
        file.close()

# Create a dummy file for demonstration purposes
with open('example.txt', 'w') as f:
    f.write('This is line 1.\n')
    f.write('This is line 2.\n')
    f.write('This is line 3.\n')

for line in read_file_lines('example.txt'):
    print(line, end='')
# Out:
# This is line 1.
# This is line 2.
# This is line 3.

# %%
#9 Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
def tem_to_fre(n):
  return (n * 9/5)+32
l1 = [10, 20, 30, 40, 50]

Fahrenheit_temp = list(map(tem_to_fre, l1))
print(Fahrenheit_temp)
# Out:
# [50.0, 68.0, 86.0, 104.0, 122.0]

# %%
#10 Create a Python program that uses `filter()` to remove all the vowels from a given string.
def not_vowel(n):
  vowels = 'aeiouAEIOU'
  return n not in vowels

xyz = 'pwskills'

string = filter(not_vowel,xyz)

# %%
#11
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result = list(map(lambda order : (order[0], (order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0))), orders))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
